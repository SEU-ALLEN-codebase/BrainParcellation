# %%
import pandas as pd
import numpy as np
import scanpy as sc

# %%
parc_id_table_path = 'gene/parcellation_to_parcellation_term_membership_acronym.csv'
parc_id_table = pd.read_csv(parc_id_table_path)

# %%
parc_id_match = {}
id_parc_match = {}
for i in range(len(parc_id_table)):
    parc_id_match[parc_id_table['parcellation_index'].iloc[i]] = parc_id_table['substructure'].iloc[i]
    id_parc_match[parc_id_table['substructure'].iloc[i]] = parc_id_table['parcellation_index'].iloc[i]

# %%
T1 = pd.read_csv('gene/screened1_matrix.csv')

# %%
c1_table_path = 'gene/cell_metadata_with_cluster_annotation_1.csv'
c1_table = pd.read_csv(c1_table_path)

# %%
annotation_table_path = 'gene/41586_2023_6812_MOESM8_ESM.xlsx'
annotation_table = pd.read_excel(annotation_table_path)

# %%
subclass_to_neighborhood = {}
for i in np.unique(annotation_table['subclass_id']):
     neigh_rowid = annotation_table[annotation_table['subclass_id'] == i].index[0]
     neigh = annotation_table['neighborhood'].iloc[neigh_rowid]
     subclass_to_neighborhood[i] = neigh

# %%
import glob
import os
import sys
sys.path.append("../pylib-main")
from file_io import load_image
from anatomy.anatomy_config import REGION671
import json

# %%
parc_id_match_reverse = {}
for k,v in parc_id_match.items():
    parc_id_match_reverse[v] = k

# %%
tree_json_path = 'tree_yzx.json'
with open(tree_json_path, 'r') as file:
    tree_json = json.load(file)

# %%
brain_to_id = {}
id_to_brain = {}
brain_id_path = {}
for i in range(len(tree_json)):
    bid = tree_json[i]['id']
    acronym = tree_json[i]['acronym']
    p = tree_json[i]['structure_id_path']
    if bid not in brain_to_id:
        brain_to_id[bid] = acronym
        id_to_brain[acronym] = bid
    if bid not in brain_id_path:
        brain_id_path[bid] = p

# %%
major_BS = [688,549,623,313,1065,512,1097]
major_BS_name = ['CTX','TH','CNU','MB','HB','CB','HY','others']
region_Rough = {}
for i in REGION671:
    tmp_p = brain_id_path[i]
    flag = False
    for j in range(len(major_BS)):
        if major_BS[j] in tmp_p:
            region_Rough[brain_to_id[i]] = major_BS_name[j]
            flag = True
    if flag == False:
        region_Rough[brain_to_id[i]] = major_BS_name[len(major_BS_name)-1]

# %%
col_s = T1.columns[1:1123]

# %%
from scipy.spatial.distance import cdist
from sklearn import preprocessing

# %%
R_name_list = []
final_parc_folder = 'lyf/output_full_r671'
for f in glob.glob(final_parc_folder+"/*"):
    f_name = os.path.basename(f)
    region_id = int(f_name.split(".")[0].split("parc_region")[1])
    R_name = brain_to_id[region_id]
    R_name_list.append(R_name)

# %%
expression_df = []
selected_R = []
exp_regions = []
exp_parc_ids = []
Gclass_label = []
Gsubclass_label = []
Gcluster_label = []
for n in R_name_list:
    if n not in parc_id_match_reverse:
        acronym_name = n+"-unassigned"
    else:
        acronym_name = n
    if acronym_name in parc_id_match_reverse:
        nid = parc_id_match_reverse[acronym_name]
        rows1 = T1[T1['parcellation_index']==nid]
        s_names = np.array(rows1['cell_label'])
        c_df = c1_table[c1_table['cell_label'].isin(s_names)]
        R_df_tmp = pd.merge(c_df,rows1,on='cell_label')
        
        if len(rows1) > 0:
            region_id = id_to_brain[n]
            mask_path = 'lyf/output_full_r671/parc_region'+str(region_id)+'.nrrd'
            if not os.path.exists(mask_path):
                continue
            parc_mask_tmp = load_image(mask_path)

            tmp_df = R_df_tmp.copy()
            tmp_df['x_y'] = round(tmp_df['x_y']*40).astype(int)
            tmp_df['y_y'] = round(tmp_df['y_y']*40).astype(int)
            tmp_df['z_y'] = round(tmp_df['z_y']*40)
            tmp_df['z_y'] = tmp_df['z_y'].apply(lambda x: 456-x if x<228 else x)
            tmp_df['z_y'] = tmp_df['z_y'].astype(int)
            label_tmp = parc_mask_tmp[tmp_df['z_y'],tmp_df['y_y'],tmp_df['x_y']]
            # print(np.unique(label_tmp))
            gclass = tmp_df['class'].apply(lambda x:x.split(' ')[0])
            gsubclass = tmp_df['subclass'].apply(lambda x:x.split(' ')[0])
            gcluster = tmp_df['cluster_alias']
            
            for j in range(1,np.max(label_tmp)+1):
                rows_parc = tmp_df[label_tmp == j]
                if len(rows_parc) > 0:
                    exp_regions.append(n)
                    exp_parc_ids.append(j)
                    expression_df.append(np.array(rows_parc[col_s].mean()))
                    Gclass_label.append(gclass[label_tmp == j])
                    Gsubclass_label.append(gsubclass[label_tmp == j]) 
                    Gcluster_label.append(gcluster[label_tmp == j])   
            selected_R.append(n)

# %%
expression_df = np.array(expression_df)
S_exp1 = (expression_df-np.mean(expression_df,axis=0))/np.std(expression_df,axis=0)
scaler = preprocessing.Normalizer(norm='l2')
S_exp2 = scaler.fit_transform(S_exp1)

D_exp = cdist(S_exp2,S_exp2,metric = 'cosine')
D_exp2 = (D_exp.max()-D_exp)/D_exp.max()

# %%
R_gene_parc = [region_Rough[x] for x in exp_regions]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
cmap = mpl.cm.rainbow
color_hm = cmap(np.linspace(0,1,len(major_BS_name)))
color_hm2 = [mpl.colors.rgb2hex(i,keep_alpha=False) for i in color_hm]
c = dict(zip(major_BS_name,color_hm2))
row_c = list(map(lambda x:c[x], R_gene_parc))
# sns.set(style="ticks", rc={'ytick.right':False,'ytick.left':False,'xtick.bottom':False,'xtick.top':False})
g_exp = sns.clustermap(data = D_exp2,
                       row_colors = row_c,
                       cmap='BuGn'
                       )
g_exp.ax_heatmap.set_xticks(np.arange(len(exp_regions)))
g_exp.ax_heatmap.set_yticks(np.arange(len(exp_regions)))

xticklabels = g_exp.data2d.columns
yticklabels = g_exp.data2d.columns

interval = 10
g_exp.ax_heatmap.set_xticklabels(
     [exp_regions[int(label)] if i % interval == 0 else '' for i,label in enumerate(xticklabels)],
     rotation=70,fontsize=5
)
g_exp.ax_heatmap.set_yticklabels(
     [exp_regions[int(label)] if i % interval == 0 else '' for i,label in enumerate(yticklabels)],
     rotation=0,fontsize=5
)

g_exp.ax_heatmap.tick_params(length=0)
# plt.savefig('all_figs/Fig5/gene_matrix_full2_avgLog.png',dpi=500)
# Out:
# /home/penglab/anaconda3/envs/python310/lib/python3.10/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /home/penglab/anaconda3/envs/python310/lib/python3.10/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
class_stats = np.zeros((len(D_exp2),29))
reordered_index = g_exp.dendrogram_col.reordered_ind
for i in range(len(reordered_index)):
     class_rows = np.array(Gclass_label[reordered_index[i]])
     tmp_classes = np.unique(class_rows)
     total_N = len(class_rows)
     for j in tmp_classes:
          n = len(class_rows[class_rows == j])
          class_stats[i,int(j)-1] = n/total_N*100

# %%
class_stats = np.array(class_stats)

# %%
cg = sns.clustermap(class_stats,row_cluster=False,col_cluster=True)
# Out:
# /home/penglab/anaconda3/envs/python310/lib/python3.10/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
reordered_cg = cg.dendrogram_col.reordered_ind

# %%
class_stats_reorder = class_stats[:,reordered_cg]

# %%
plt.figure(figsize=(3,8))
sns.heatmap(class_stats_reorder,cmap='Reds')
# plt.savefig('all_figs/Fig5/Gclass.png',dpi=300)
# Out:
# <Axes: >

# %%
neighborhood_num = {'Pallium-Glut':0,'Subpallium-GABA':1,
                    'HY-EA-Glut-GABA':2,'TH-EPI-Glut':3,
                    'MB-HB-Glut-Sero-Dopa':4,'MB-HB-CB-GABA':5}

neighborhood_stats = np.zeros((len(D_exp2),6))
for i in range(len(reordered_index)):
     subclass_rows = np.array(Gsubclass_label[reordered_index[i]])
     tmp_subclasses = np.unique(subclass_rows)
     total_N = len(subclass_rows)
     tmp_neigh = {}
     for j in tmp_subclasses:
          tmp_n = subclass_to_neighborhood[int(j)]
          if ";" in tmp_n:
               tmp_n = tmp_n.split(";")[0]
          n = len(subclass_rows[subclass_rows == j])
          if tmp_n not in neighborhood_num:
               total_N = total_N - n
               continue
          if tmp_n not in tmp_neigh:
               tmp_neigh[neighborhood_num[tmp_n]] = n
          else:
               tmp_neigh[neighborhood_num[tmp_n]] += n
               
     for k,v in tmp_neigh.items(): 
          neighborhood_stats[i,k] = v/total_N*100

# %%
neighborhood_stats = np.array(neighborhood_stats)

# %%
ng = sns.clustermap(neighborhood_stats,row_cluster=False,col_cluster=True)

# %%
ng_reorder = ng.dendrogram_col.reordered_ind
neighborhood_stats_reorder = neighborhood_stats[:,ng_reorder]

# %%
plt.figure(figsize=(1,8))
sns.heatmap(neighborhood_stats_reorder,cmap='Reds')
# plt.savefig('all_figs/Fig5/Gneighborhood.png',dpi=300)
# Out:
# <Axes: >

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
from esda.moran import Moran
import pysal.lib as pslib
# import warnings
from scipy.spatial import distance_matrix
def moran_calc2(num_cluster,labels, coords):
    # warnings.filterwarnings('ignore',category=UserWarning)
    N = len(coords)
    if N > 60000:    
        ids = [10*i for i in range(int(np.floor(N/10)))]
        coords = coords[ids,:]
        labels = np.array(labels)[ids]
    dist_m = distance_matrix(coords,coords)
    thres = np.percentile(dist_m,25)
    weights = pslib.weights.DistanceBand.from_array(coords, threshold=thres)
    moran = Moran(labels, weights)
    avgI = moran.I
    pI = moran.p_norm
    zI = moran.z_norm
    return avgI,pI,zI

# %%
T_info1 = pd.read_csv('gene/screened_info1.csv')

# %%
# %%capture

moran_func = True
if moran_func:
    moran_r, moran_scores,moran_r_parc, moran_scores_parc, moran_parc_ids = [],[],[],[],[]
else:
    std_r, std_scores,std_r_parc, std_scores_parc, std_parc_ids, std_delta_parc, cv_parc= [],[],[],[],[],[],[]

for i in REGION671:
    mask_path = 'lyf/output_full_r671/parc_region'+str(i)+'.nrrd'
    if not os.path.exists(mask_path):
        continue
    parc_mask_tmp = load_image(mask_path)
    N_parc = np.max(parc_mask_tmp)
    if N_parc <2:
        continue
    region_id = i
    acronym_name = brain_to_id[region_id]
    if acronym_name not in id_parc_match:
        acronym_name = acronym_name+"-unassigned"
    if acronym_name not in id_parc_match:
        continue
    r_name = id_parc_match[acronym_name]
    
    if moran_func:
        t_tmp_df = T_info1[T_info1['parcellation_index']==r_name]
        if len(t_tmp_df) < 10:
            continue
        s_names = np.array(t_tmp_df['cell_label'])
        c_tmp_df = c1_table[c1_table['cell_label'].isin(s_names)]
        R_df_tmp = pd.merge(c_tmp_df,t_tmp_df,on='cell_label')
        coords = R_df_tmp[['x_y','y_y','z_y']].values
        R_df_tmp['x_y'] = round(R_df_tmp['x_y']*40).astype(int)
        R_df_tmp['y_y'] = round(R_df_tmp['y_y']*40).astype(int)
        R_df_tmp['z_y'] = round(R_df_tmp['z_y']*40)
        R_df_tmp['z_y'] = R_df_tmp['z_y'].apply(lambda x: 456-x if x<228 else x)
        R_df_tmp['z_y'] = R_df_tmp['z_y'].astype(int)    
        g_labels = R_df_tmp['cluster'].apply(lambda x: int(x.split(' ')[0]))
        num_cluster = len(np.unique(g_labels))
        
        parc_labels = parc_mask_tmp[R_df_tmp['z_y'],R_df_tmp['y_y'],R_df_tmp['x_y']]
    
        moran_score,moran_pi,moran_zi = moran_calc2(num_cluster,g_labels, coords)
        moran_scores.append(moran_score)
        moran_r.append(brain_to_id[region_id])  
        
        del t_tmp_df,c_tmp_df, parc_mask_tmp
    else:
        t_tmp_df = T1[T1['parcellation_index']==r_name]
        if len(t_tmp_df) < 10:
            continue

        R_df_tmp = t_tmp_df

        R_df_tmp['x'] = round(R_df_tmp['x']*40).astype(int)
        R_df_tmp['y'] = round(R_df_tmp['y']*40).astype(int)
        R_df_tmp['z'] = round(R_df_tmp['z']*40)
        R_df_tmp['z'] = R_df_tmp['z'].apply(lambda x: 456-x if x<228 else x)
        R_df_tmp['z'] = R_df_tmp['z'].astype(int)

        parc_labels = parc_mask_tmp[R_df_tmp['z'],R_df_tmp['y'],R_df_tmp['x']]
     
        ss = StandardScaler()
        R_df_scaled = ss.fit_transform(R_df_tmp[col_s])
        pca = PCA(n_components=3)
        R_df_trans = pca.fit_transform(R_df_scaled)
        std_r.append(brain_to_id[region_id])
        top_std = np.std(R_df_trans,axis=0)
        std_scores.append(np.mean(top_std))
        
        # col_sum = np.sum(R_df_tmp[col_s])
        # col_sum_sorted = np.sort(col_sum)
        # nc = len(col_sum_sorted)
        # count_add = 0
        # col_ids = []
        # for c in range(3):
        #     v = col_sum_sorted[nc-c-1]
        #     idlist = np.where(col_sum == v)[0]
        #     for d in idlist:
        #         col_ids.append(col_s[d])
        #         count_add += 1
        #         if count_add  > 3:
        #             break
        #     if count_add > 3: 
        #         break
        
        # cv_overall = np.std(R_df_tmp[col_ids],axis=0)/np.mean(R_df_tmp[col_ids],axis=0)
    
        del t_tmp_df,parc_mask_tmp
    
    for j in range(1,N_parc+1):
        if moran_func:
            g2 = g_labels[parc_labels == j]
            if len(g2) <10:
                continue
            num_cluster_tmp = len(np.unique(g2))
            coords_tmp = coords[parc_labels == j,:]
            moran_score2,moran_pi2,moran_zi2 = moran_calc2(num_cluster_tmp,g2, coords_tmp)
            moran_scores_parc.append(moran_score2)
            moran_parc_ids.append(j)
            moran_r_parc.append(brain_to_id[region_id])
            
            del coords_tmp
        else: 
            tmp_rows = R_df_trans[parc_labels == j]
            if len(tmp_rows) <10:
                continue
            std_r_parc.append(brain_to_id[region_id])
            std_parc_ids.append(j)
        
            top_std_tmp = np.std(tmp_rows,axis=0)
            std_scores_parc.append(np.mean(top_std_tmp))
            std_delta_parc.append(np.mean(top_std_tmp)-np.mean(top_std))
            
            tmp_rows2 = R_df_tmp[parc_labels == j][col_ids]
            # cv_org = np.std(tmp_rows2,axis=0)/np.mean(tmp_rows2,axis=0)
            # cv_parc.append(np.mean(cv_org-cv_overall))
            del tmp_rows,tmp_rows2
    del R_df_tmp

# %%
def load_features(mefile, scale=25., feat_type='mRMR', flipLR=True):
    df = pd.read_csv(mefile, index_col=0, comment='#')
    
    if feat_type == 'full':
        cols = df.columns
        fnames = [fname for fname in cols if fname[-3:] == '_me']
    elif feat_type == 'mRMR':
        # Features selected by mRMR
        fnames = mRMR_f3me
    elif feat_type == 'PCA':
        fnames = ['pca_feat1', 'pca_feat2', 'pca_feat3']
    else:
        raise ValueError("Unsupported feature types")

    # standardize
    tmp = df[fnames]
    tmp = (tmp - tmp.mean()) / (tmp.std() + 1e-10)
    df[fnames] = tmp

    # scaling the coordinates to CCFv3-25um space
    df['soma_x'] /= scale
    df['soma_y'] /= scale
    df['soma_z'] /= scale
    # we should remove the out-of-region coordinates
    zdim,ydim,xdim = (456,320,528)   # dimensions for CCFv3-25um atlas
    in_region = (df['soma_x'] >= 0) & (df['soma_x'] < xdim) & \
                (df['soma_y'] >= 0) & (df['soma_y'] < ydim) & \
                (df['soma_z'] >= 0) & (df['soma_z'] < zdim)
    df = df[in_region]
    print(f'Filtered out {in_region.shape[0] - df.shape[0]}')

    if flipLR:
        # mirror right hemispheric points to left hemisphere
        zdim2 = zdim // 2
        nzi = (df['soma_z'] < zdim2).values.nonzero()
        loci = df.index[nzi]
        df.loc[loci, 'soma_z'] = zdim - df.loc[loci, 'soma_z']

    return df, fnames

# %%
me_file_path = 'BrainParcellation/microenviron/data/mefeatures_100K_with_PCAfeatures3.csv'
me_df_new, fnames_new = load_features(me_file_path, scale=25., feat_type='full', flipLR=True)
# Out:
# Filtered out 0

# %%
import pymrmr

# %%
### L2/3
def moran_calc_me(df, fnames):
    coords = df[['soma_x', 'soma_y', 'soma_z']]/40
    dist_m = distance_matrix(coords,coords)
    thres = np.percentile(dist_m,25)
    weights = pslib.weights.DistanceBand.from_array(coords.values, threshold=thres,binary=True)
    avgI = []
    pI = []
    zI = []
    for fn in fnames:
        moran = Moran(df[fn], weights)
        avgI.append(moran.I)
        pI.append(moran.p_norm)
        zI.append(moran.z_norm)
    return avgI,pI,zI

# %%
# %%capture
moran_func2 = True
if moran_func2:
    moran_regions,moran_parcID,moran_I_all,moran_me_I,moran_me_r= [],[],[],[],[]
else:
    fstd_regions,fstd_parcID,fstd_I_all,fstd_me_I,fstd_me_r,fstd_delta_all,cv_parc_me= [],[],[],[],[],[],[]

for i in REGION671:
    mask_file = 'lyf/output_full_r671/parc_region'+str(i)+'.nrrd'
    if os.path.exists(mask_file):
        mask = load_image(mask_file)
        N_parc = np.max(mask)
        
        me_df_r = me_df_new[me_df_new['region_id_r671']==i]
        print(len(me_df_r))
        if len(me_df_r) < 10:
            continue
        if N_parc <2:
            continue
        
        me_df_r2 = me_df_r.copy()
        me_df_r2['soma_z'] = round(me_df_r2['soma_z']).astype(int)
        me_df_r2['soma_x'] = round(me_df_r2['soma_x']).astype(int)
        me_df_r2['soma_y'] = round(me_df_r2['soma_y']).astype(int)
    
        parc_labels = mask[me_df_r2['soma_z'],me_df_r2['soma_y'],me_df_r2['soma_x']]
        
        del mask
        
        if moran_func2:
            me_df_r2 = me_df_r2[fnames_new]
            me_df_r2.insert(loc=0,column='parc_id',value=parc_labels)
        
            mrmr_F = pymrmr.mRMR(me_df_r2,'MIQ',3)
        
            avgI_me,pI_me,zI_me = moran_calc_me(me_df_r, mrmr_F)
            moran_me_I.append(np.mean(avgI_me))
            moran_me_r.append(brain_to_id[i]) 
                
        else:
            tmp_scaled = StandardScaler().fit_transform(me_df_r[fnames_new])
        
            pca = PCA(n_components=3)
            tmp_trans = pca.fit_transform(tmp_scaled)
            top_std = np.std(tmp_trans,axis=0)
            meanSTD = np.mean(top_std)
            fstd_me_I.append(meanSTD)
            fstd_me_r.append(brain_to_id[i]) 
            
            me_df_r2 = me_df_r2[fnames_new]
            me_df_r2.insert(loc=0,column='parc_id',value=parc_labels)
        
            mrmr_F = pymrmr.mRMR(me_df_r2,'MIQ',3)
            
            cv_overall = np.std(me_df_r[mrmr_F],axis=0)/np.mean(me_df_r[mrmr_F],axis=0)
            del tmp_scaled

        for j in range(1,N_parc+1):
            if len(me_df_r[parc_labels == j]) < 10:
                continue
            
            if moran_func2:
                me_tmp = me_df_r[parc_labels == j]            
                avgI,pI,zI = moran_calc_me(me_tmp, mrmr_F)
                
                moran_I_all.append(np.mean(avgI))
                moran_regions.append(brain_to_id[i])
                moran_parcID.append(j)
                
                del me_tmp
            else:
                me_tmp = tmp_trans[parc_labels==j,:]
                top_std_tmp = np.std(me_tmp,axis=0)
                fstd_I_all.append(np.mean(top_std_tmp))
                fstd_regions.append(brain_to_id[i])
                fstd_parcID.append(j)
                fstd_delta_all.append(np.mean(top_std_tmp) - meanSTD)
                
                me_tmp2 = me_df_r[parc_labels == j][mrmr_F]
                cv_org = np.std(me_tmp2,axis=0)/np.mean(me_tmp2,axis=0)
                cv_parc_me.append(np.mean(cv_org-cv_overall))
                del me_tmp
        del me_df_r, me_df_r2
# Out:
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 5 	 OverallWidth_me 	 0.497
# 2 	 19 	 pc11_me 	 0.431
# 3 	 20 	 pc12_me 	 0.416
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 5 	 OverallWidth_me 	 0.497
# 2 	 21 	 pc13_me 	 3.506
# 3 	 1 	 Stems_me 	 3.103
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 5 	 OverallWidth_me 	 0.159
# 2 	 24 	 pca_vr3_me 	 0.117
# 3 	 23 	 pca_vr2_me 	 0.065
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 5 	 OverallWidth_me 	 0.159
# 2 	 10 	 MaxEuclideanDistance_me 	 2.475
# 3 	 7 	 OverallDepth_me 	 2.804
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.072
# 2 	 5 	 OverallWidth_me 	 0.068
# 3 	 1 	 Stems_me 	 0.065
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.072
# 2 	 13 	 AverageContraction_me 	 4.443
# 3 	 5 	 OverallWidth_me 	 2.676
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.376
# 2 	 12 	 MaxBranchOrder_me 	 0.234
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 0.197
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.376
# 2 	 20 	 pc12_me 	 2.677
# 3 	 9 	 Volume_me 	 2.601
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 6 	 OverallHeight_me 	 0.211
# 2 	 20 	 pc12_me 	 0.210
# 3 	 21 	 pc13_me 	 0.192
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 6 	 OverallHeight_me 	 0.211
# 2 	 5 	 OverallWidth_me 	 4.870
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 3.896
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.117
# 2 	 17 	 AverageBifurcationAngleRemote_me 	 0.094
# 3 	 5 	 OverallWidth_me 	 0.084
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.117
# 2 	 21 	 pc13_me 	 5.321
# 3 	 5 	 OverallWidth_me 	 5.936
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 11 	 MaxPathDistance_me 	 0.195
# 2 	 5 	 OverallWidth_me 	 0.170
# 3 	 3 	 Branches_me 	 0.167
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 11 	 MaxPathDistance_me 	 0.195
# 2 	 7 	 OverallDepth_me 	 1.011
# 3 	 14 	 AverageFragmentation_me 	 1.263
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.186
# 2 	 1 	 Stems_me 	 0.159
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 0.136
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.186
# 2 	 13 	 AverageContraction_me 	 7.385
# 3 	 1 	 Stems_me 	 4.269
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.082
# 2 	 15 	 AverageParent-daughterRatio_me 	 0.070
# 3 	 12 	 MaxBranchOrder_me 	 0.069
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.082
# 2 	 17 	 AverageBifurcationAngleRemote_me 	 1.777
# 3 	 19 	 pc11_me 	 2.415
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.219
# 2 	 11 	 MaxPathDistance_me 	 0.133
# 3 	 7 	 OverallDepth_me 	 0.119
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.219
# 2 	 13 	 AverageContraction_me 	 10.585
# 3 	 8 	 Length_me 	 5.783
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.179
# 2 	 22 	 pca_vr1_me 	 0.149
# 3 	 9 	 Volume_me 	 0.125
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.179
# 2 	 15 	 AverageParent-daughterRatio_me 	 3.377
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 2.789
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.489
# 2 	 8 	 Length_me 	 0.336
# 3 	 3 	 Branches_me 	 0.336
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.489
# 2 	 9 	 Volume_me 	 4.397
# 3 	 13 	 AverageContraction_me 	 2.500
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.174
# 2 	 2 	 Bifurcations_me 	 0.170
# 3 	 4 	 Tips_me 	 0.169
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.174
# 2 	 20 	 pc12_me 	 1.787
# 3 	 18 	 HausdorffDimension_me 	 2.808
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.428
# 2 	 21 	 pc13_me 	 0.425
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 0.395
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.428
# 2 	 9 	 Volume_me 	 2.682
# 3 	 8 	 Length_me 	 3.108
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.504
# 2 	 17 	 AverageBifurcationAngleRemote_me 	 0.409
# 3 	 21 	 pc13_me 	 0.401
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.504
# 2 	 6 	 OverallHeight_me 	 3.182
# 3 	 21 	 pc13_me 	 2.241
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 20 	 pc12_me 	 0.273
# 2 	 9 	 Volume_me 	 0.252
# 3 	 3 	 Branches_me 	 0.244
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 20 	 pc12_me 	 0.273
# 2 	 5 	 OverallWidth_me 	 3.834
# 3 	 19 	 pc11_me 	 2.470
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.462
# 2 	 24 	 pca_vr3_me 	 0.431
# 3 	 1 	 Stems_me 	 0.359
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.462
# 2 	 23 	 pca_vr2_me 	 4.748
# 3 	 13 	 AverageContraction_me 	 5.159
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.143
# 2 	 23 	 pca_vr2_me 	 0.107
# 3 	 1 	 Stems_me 	 0.086
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.143
# 2 	 5 	 OverallWidth_me 	 2.929
# 3 	 13 	 AverageContraction_me 	 3.647
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 16 	 AverageBifurcationAngleLocal_me 	 0.097
# 2 	 13 	 AverageContraction_me 	 0.072
# 3 	 19 	 pc11_me 	 0.060
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 16 	 AverageBifurcationAngleLocal_me 	 0.097
# 2 	 13 	 AverageContraction_me 	 5.746
# 3 	 7 	 OverallDepth_me 	 1.467
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.126
# 2 	 5 	 OverallWidth_me 	 0.122
# 3 	 22 	 pca_vr1_me 	 0.120
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.126
# 2 	 16 	 AverageBifurcationAngleLocal_me 	 2.110
# 3 	 5 	 OverallWidth_me 	 1.294
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.266
# 2 	 18 	 HausdorffDimension_me 	 0.252
# 3 	 4 	 Tips_me 	 0.249
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.266
# 2 	 10 	 MaxEuclideanDistance_me 	 3.258
# 3 	 21 	 pc13_me 	 4.373
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.352
# 2 	 21 	 pc13_me 	 0.225
# 3 	 24 	 pca_vr3_me 	 0.221
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.352
# 2 	 17 	 AverageBifurcationAngleRemote_me 	 1.382
# 3 	 12 	 MaxBranchOrder_me 	 1.209
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 5 	 OverallWidth_me 	 0.197
# 2 	 8 	 Length_me 	 0.190
# 3 	 18 	 HausdorffDimension_me 	 0.168
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 5 	 OverallWidth_me 	 0.197
# 2 	 21 	 pc13_me 	 18.237
# 3 	 14 	 AverageFragmentation_me 	 3.495
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.252
# 2 	 19 	 pc11_me 	 0.245
# 3 	 22 	 pca_vr1_me 	 0.230
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.252
# 2 	 15 	 AverageParent-daughterRatio_me 	 1.129
# 3 	 19 	 pc11_me 	 0.946
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.080
# 2 	 24 	 pca_vr3_me 	 0.061
# 3 	 22 	 pca_vr1_me 	 0.059
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.080
# 2 	 7 	 OverallDepth_me 	 2.710
# 3 	 3 	 Branches_me 	 1.627
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 20 	 pc12_me 	 0.273
# 2 	 22 	 pca_vr1_me 	 0.232
# 3 	 23 	 pca_vr2_me 	 0.214
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 20 	 pc12_me 	 0.273
# 2 	 10 	 MaxEuclideanDistance_me 	 2.670
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 2.951
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.380
# 2 	 13 	 AverageContraction_me 	 0.275
# 3 	 22 	 pca_vr1_me 	 0.257
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.380
# 2 	 16 	 AverageBifurcationAngleLocal_me 	 7.041
# 3 	 10 	 MaxEuclideanDistance_me 	 3.002
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 13 	 AverageContraction_me 	 0.180
# 2 	 1 	 Stems_me 	 0.075
# 3 	 7 	 OverallDepth_me 	 0.075
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 13 	 AverageContraction_me 	 0.180
# 2 	 21 	 pc13_me 	 2.931
# 3 	 11 	 MaxPathDistance_me 	 2.525
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.092
# 2 	 14 	 AverageFragmentation_me 	 0.076
# 3 	 7 	 OverallDepth_me 	 0.076
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.092
# 2 	 14 	 AverageFragmentation_me 	 2.067
# 3 	 17 	 AverageBifurcationAngleRemote_me 	 1.556
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 12 	 MaxBranchOrder_me 	 0.163
# 2 	 18 	 HausdorffDimension_me 	 0.144
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 0.120
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 12 	 MaxBranchOrder_me 	 0.163
# 2 	 17 	 AverageBifurcationAngleRemote_me 	 7.523
# 3 	 22 	 pca_vr1_me 	 2.930
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.565
# 2 	 14 	 AverageFragmentation_me 	 0.436
# 3 	 22 	 pca_vr1_me 	 0.397
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.565
# 2 	 10 	 MaxEuclideanDistance_me 	 2.455
# 3 	 14 	 AverageFragmentation_me 	 2.858
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.130
# 2 	 18 	 HausdorffDimension_me 	 0.104
# 3 	 15 	 AverageParent-daughterRatio_me 	 0.092
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.130
# 2 	 22 	 pca_vr1_me 	 3.720
# 3 	 20 	 pc12_me 	 2.890
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.235
# 2 	 24 	 pca_vr3_me 	 0.178
# 3 	 22 	 pca_vr1_me 	 0.153
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.235
# 2 	 5 	 OverallWidth_me 	 7.628
# 3 	 13 	 AverageContraction_me 	 3.433
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.383
# 2 	 12 	 MaxBranchOrder_me 	 0.336
# 3 	 14 	 AverageFragmentation_me 	 0.324
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.383
# 2 	 12 	 MaxBranchOrder_me 	 3.222
# 3 	 24 	 pca_vr3_me 	 2.978
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 3 	 Branches_me 	 0.831
# 2 	 2 	 Bifurcations_me 	 0.831
# 3 	 8 	 Length_me 	 0.741
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 3 	 Branches_me 	 0.831
# 2 	 23 	 pca_vr2_me 	 1.275
# 3 	 15 	 AverageParent-daughterRatio_me 	 1.377
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 2 	 Bifurcations_me 	 0.391
# 2 	 13 	 AverageContraction_me 	 0.390
# 3 	 3 	 Branches_me 	 0.380
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 2 	 Bifurcations_me 	 0.391
# 2 	 13 	 AverageContraction_me 	 10.509
# 3 	 9 	 Volume_me 	 3.304
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 1 	 Stems_me 	 0.394
# 2 	 5 	 OverallWidth_me 	 0.370
# 3 	 21 	 pc13_me 	 0.319
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 1 	 Stems_me 	 0.394
# 2 	 2 	 Bifurcations_me 	 24.262
# 3 	 20 	 pc12_me 	 6.300
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.241
# 2 	 5 	 OverallWidth_me 	 0.165
# 3 	 23 	 pca_vr2_me 	 0.133
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.241
# 2 	 14 	 AverageFragmentation_me 	 9.150
# 3 	 22 	 pca_vr1_me 	 6.239
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.214
# 2 	 12 	 MaxBranchOrder_me 	 0.175
# 3 	 6 	 OverallHeight_me 	 0.138
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.214
# 2 	 22 	 pca_vr1_me 	 3.216
# 3 	 15 	 AverageParent-daughterRatio_me 	 3.818
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.246
# 2 	 14 	 AverageFragmentation_me 	 0.228
# 3 	 17 	 AverageBifurcationAngleRemote_me 	 0.193
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.246
# 2 	 2 	 Bifurcations_me 	 1.762
# 3 	 18 	 HausdorffDimension_me 	 1.324
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.109
# 2 	 16 	 AverageBifurcationAngleLocal_me 	 0.079
# 3 	 14 	 AverageFragmentation_me 	 0.073
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.109
# 2 	 2 	 Bifurcations_me 	 2.130
# 3 	 24 	 pca_vr3_me 	 3.262
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.189
# 2 	 9 	 Volume_me 	 0.113
# 3 	 12 	 MaxBranchOrder_me 	 0.106
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.189
# 2 	 10 	 MaxEuclideanDistance_me 	 1.526
# 3 	 23 	 pca_vr2_me 	 2.299
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 4 	 Tips_me 	 0.154
# 2 	 3 	 Branches_me 	 0.154
# 3 	 2 	 Bifurcations_me 	 0.148
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 4 	 Tips_me 	 0.154
# 2 	 21 	 pc13_me 	 2.119
# 3 	 20 	 pc12_me 	 2.059
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.248
# 2 	 6 	 OverallHeight_me 	 0.208
# 3 	 23 	 pca_vr2_me 	 0.161
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.248
# 2 	 24 	 pca_vr3_me 	 3.552
# 3 	 13 	 AverageContraction_me 	 2.466
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 13 	 AverageContraction_me 	 0.382
# 2 	 7 	 OverallDepth_me 	 0.347
# 3 	 24 	 pca_vr3_me 	 0.307
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 13 	 AverageContraction_me 	 0.382
# 2 	 9 	 Volume_me 	 6.854
# 3 	 10 	 MaxEuclideanDistance_me 	 5.185
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 11 	 MaxPathDistance_me 	 0.297
# 2 	 19 	 pc11_me 	 0.276
# 3 	 14 	 AverageFragmentation_me 	 0.262
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 11 	 MaxPathDistance_me 	 0.297
# 2 	 5 	 OverallWidth_me 	 3.559
# 3 	 24 	 pca_vr3_me 	 2.623
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.377
# 2 	 9 	 Volume_me 	 0.368
# 3 	 1 	 Stems_me 	 0.337
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.377
# 2 	 13 	 AverageContraction_me 	 2.367
# 3 	 7 	 OverallDepth_me 	 3.304
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.586
# 2 	 6 	 OverallHeight_me 	 0.552
# 3 	 5 	 OverallWidth_me 	 0.532
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.586
# 2 	 9 	 Volume_me 	 3.777
# 3 	 10 	 MaxEuclideanDistance_me 	 5.235
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.227
# 2 	 13 	 AverageContraction_me 	 0.214
# 3 	 12 	 MaxBranchOrder_me 	 0.189
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.227
# 2 	 7 	 OverallDepth_me 	 4.230
# 3 	 5 	 OverallWidth_me 	 4.434
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.305
# 2 	 14 	 AverageFragmentation_me 	 0.276
# 3 	 13 	 AverageContraction_me 	 0.250
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.305
# 2 	 3 	 Branches_me 	 1.625
# 3 	 14 	 AverageFragmentation_me 	 2.070
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 13 	 AverageContraction_me 	 0.333
# 2 	 1 	 Stems_me 	 0.214
# 3 	 7 	 OverallDepth_me 	 0.175
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 13 	 AverageContraction_me 	 0.333
# 2 	 8 	 Length_me 	 8.883
# 3 	 17 	 AverageBifurcationAngleRemote_me 	 3.481
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.395
# 2 	 14 	 AverageFragmentation_me 	 0.334
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 0.248
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.395
# 2 	 10 	 MaxEuclideanDistance_me 	 1.879
# 3 	 19 	 pc11_me 	 1.472
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.234
# 2 	 5 	 OverallWidth_me 	 0.208
# 3 	 19 	 pc11_me 	 0.175
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.234
# 2 	 5 	 OverallWidth_me 	 2.303
# 3 	 12 	 MaxBranchOrder_me 	 1.842
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.165
# 2 	 9 	 Volume_me 	 0.140
# 3 	 21 	 pc13_me 	 0.134
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 17 	 AverageBifurcationAngleRemote_me 	 0.165
# 2 	 8 	 Length_me 	 2.181
# 3 	 7 	 OverallDepth_me 	 2.433
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.148
# 2 	 20 	 pc12_me 	 0.138
# 3 	 19 	 pc11_me 	 0.122
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.148
# 2 	 9 	 Volume_me 	 1.785
# 3 	 10 	 MaxEuclideanDistance_me 	 2.299
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 8 	 Length_me 	 0.177
# 2 	 2 	 Bifurcations_me 	 0.168
# 3 	 3 	 Branches_me 	 0.168
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 8 	 Length_me 	 0.177
# 2 	 21 	 pc13_me 	 2.618
# 3 	 13 	 AverageContraction_me 	 1.484
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.168
# 2 	 1 	 Stems_me 	 0.165
# 3 	 22 	 pca_vr1_me 	 0.152
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.168
# 2 	 10 	 MaxEuclideanDistance_me 	 14.291
# 3 	 14 	 AverageFragmentation_me 	 5.764
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 16 	 AverageBifurcationAngleLocal_me 	 0.587
# 2 	 19 	 pc11_me 	 0.394
# 3 	 23 	 pca_vr2_me 	 0.369
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 16 	 AverageBifurcationAngleLocal_me 	 0.587
# 2 	 5 	 OverallWidth_me 	 3.134
# 3 	 21 	 pc13_me 	 4.432
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.560
# 2 	 15 	 AverageParent-daughterRatio_me 	 0.546
# 3 	 21 	 pc13_me 	 0.538
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.560
# 2 	 8 	 Length_me 	 4.142
# 3 	 10 	 MaxEuclideanDistance_me 	 4.391
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.327
# 2 	 15 	 AverageParent-daughterRatio_me 	 0.321
# 3 	 14 	 AverageFragmentation_me 	 0.309
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 18 	 HausdorffDimension_me 	 0.327
# 2 	 10 	 MaxEuclideanDistance_me 	 5.834
# 3 	 21 	 pc13_me 	 5.993
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.102
# 2 	 21 	 pc13_me 	 0.093
# 3 	 1 	 Stems_me 	 0.086
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 23 	 pca_vr2_me 	 0.102
# 2 	 6 	 OverallHeight_me 	 3.774
# 3 	 24 	 pca_vr3_me 	 2.100
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 2 	 Bifurcations_me 	 0.193
# 2 	 3 	 Branches_me 	 0.187
# 3 	 8 	 Length_me 	 0.180
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 2 	 Bifurcations_me 	 0.193
# 2 	 19 	 pc11_me 	 1.539
# 3 	 6 	 OverallHeight_me 	 1.515
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 19 	 pc11_me 	 0.382
# ...
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.159
# 2 	 17 	 AverageBifurcationAngleRemote_me 	 0.141
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 0.137
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 9 	 Volume_me 	 0.159
# 2 	 21 	 pc13_me 	 1.609
# 3 	 17 	 AverageBifurcationAngleRemote_me 	 2.173
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 5 	 OverallWidth_me 	 0.178
# 2 	 23 	 pca_vr2_me 	 0.144
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 0.135
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 5 	 OverallWidth_me 	 0.178
# 2 	 2 	 Bifurcations_me 	 4.512
# 3 	 23 	 pca_vr2_me 	 3.519
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.277
# 2 	 10 	 MaxEuclideanDistance_me 	 0.255
# 3 	 13 	 AverageContraction_me 	 0.217
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.277
# 2 	 24 	 pca_vr3_me 	 10.315
# 3 	 15 	 AverageParent-daughterRatio_me 	 5.785
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 6 	 OverallHeight_me 	 0.166
# 2 	 5 	 OverallWidth_me 	 0.096
# 3 	 13 	 AverageContraction_me 	 0.094
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 6 	 OverallHeight_me 	 0.166
# 2 	 5 	 OverallWidth_me 	 4.460
# 3 	 13 	 AverageContraction_me 	 3.185
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 12 	 MaxBranchOrder_me 	 0.205
# 2 	 2 	 Bifurcations_me 	 0.203
# 3 	 8 	 Length_me 	 0.201
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 12 	 MaxBranchOrder_me 	 0.205
# 2 	 23 	 pca_vr2_me 	 5.787
# 3 	 10 	 MaxEuclideanDistance_me 	 4.658
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.166
# 2 	 5 	 OverallWidth_me 	 0.147
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 0.119
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.166
# 2 	 5 	 OverallWidth_me 	 7.856
# 3 	 6 	 OverallHeight_me 	 5.363
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 2 	 Bifurcations_me 	 0.339
# 2 	 20 	 pc12_me 	 0.277
# 3 	 8 	 Length_me 	 0.250
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 2 	 Bifurcations_me 	 0.339
# 2 	 11 	 MaxPathDistance_me 	 4.016
# 3 	 7 	 OverallDepth_me 	 4.003
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.529
# 2 	 17 	 AverageBifurcationAngleRemote_me 	 0.378
# 3 	 1 	 Stems_me 	 0.367
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.529
# 2 	 21 	 pc13_me 	 1.920
# 3 	 22 	 pca_vr1_me 	 2.231
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.127
# 2 	 6 	 OverallHeight_me 	 0.111
# 3 	 3 	 Branches_me 	 0.099
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.127
# 2 	 20 	 pc12_me 	 12.003
# 3 	 21 	 pc13_me 	 3.105
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.435
# 2 	 24 	 pca_vr3_me 	 0.350
# 3 	 5 	 OverallWidth_me 	 0.195
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 7 	 OverallDepth_me 	 0.435
# 2 	 13 	 AverageContraction_me 	 2.782
# 3 	 5 	 OverallWidth_me 	 2.711
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.225
# 2 	 22 	 pca_vr1_me 	 0.181
# 3 	 13 	 AverageContraction_me 	 0.145
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.225
# 2 	 21 	 pc13_me 	 3.914
# 3 	 13 	 AverageContraction_me 	 2.900
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.230
# 2 	 3 	 Branches_me 	 0.207
# 3 	 4 	 Tips_me 	 0.205
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 24 	 pca_vr3_me 	 0.230
# 2 	 18 	 HausdorffDimension_me 	 2.490
# 3 	 21 	 pc13_me 	 1.927
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.158
# 2 	 12 	 MaxBranchOrder_me 	 0.136
# 3 	 18 	 HausdorffDimension_me 	 0.133
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 14 	 AverageFragmentation_me 	 0.158
# 2 	 11 	 MaxPathDistance_me 	 5.966
# 3 	 22 	 pca_vr1_me 	 3.188
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 11 	 MaxPathDistance_me 	 0.355
# 2 	 23 	 pca_vr2_me 	 0.323
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 0.271
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 11 	 MaxPathDistance_me 	 0.355
# 2 	 23 	 pca_vr2_me 	 1.787
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 1.114
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.285
# 2 	 6 	 OverallHeight_me 	 0.264
# 3 	 14 	 AverageFragmentation_me 	 0.246
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.285
# 2 	 15 	 AverageParent-daughterRatio_me 	 5.757
# 3 	 16 	 AverageBifurcationAngleLocal_me 	 2.540
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 11 	 MaxPathDistance_me 	 0.181
# 2 	 12 	 MaxBranchOrder_me 	 0.138
# 3 	 7 	 OverallDepth_me 	 0.122
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 11 	 MaxPathDistance_me 	 0.181
# 2 	 13 	 AverageContraction_me 	 2.257
# 3 	 6 	 OverallHeight_me 	 1.923
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 1 	 Stems_me 	 0.240
# 2 	 24 	 pca_vr3_me 	 0.174
# 3 	 15 	 AverageParent-daughterRatio_me 	 0.151
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 1 	 Stems_me 	 0.240
# 2 	 15 	 AverageParent-daughterRatio_me 	 3.740
# 3 	 24 	 pca_vr3_me 	 2.145
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 6 	 OverallHeight_me 	 0.499
# 2 	 14 	 AverageFragmentation_me 	 0.497
# 3 	 17 	 AverageBifurcationAngleRemote_me 	 0.422
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 6 	 OverallHeight_me 	 0.499
# 2 	 19 	 pc11_me 	 2.329
# 3 	 14 	 AverageFragmentation_me 	 2.676
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 20 	 pc12_me 	 0.194
# 2 	 21 	 pc13_me 	 0.188
# 3 	 12 	 MaxBranchOrder_me 	 0.125
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 20 	 pc12_me 	 0.194
# 2 	 21 	 pc13_me 	 0.798
# 3 	 22 	 pca_vr1_me 	 0.769
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 8 	 Length_me 	 0.206
# 2 	 2 	 Bifurcations_me 	 0.189
# 3 	 4 	 Tips_me 	 0.179
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 8 	 Length_me 	 0.206
# 2 	 13 	 AverageContraction_me 	 1.335
# 3 	 15 	 AverageParent-daughterRatio_me 	 1.732
#
#
#  *** This program and the respective minimum Redundancy Maximum Relevance (mRMR)
#      algorithm were developed by Hanchuan Peng <hanchuan.peng@gmail.com>for
#      the paper
#      "Feature selection based on mutual information: criteria of
#       max-dependency, max-relevance, and min-redundancy,"
#       Hanchuan Peng, Fuhui Long, and Chris Ding,
#       IEEE Transactions on Pattern Analysis and Machine Intelligence,
#       Vol. 27, No. 8, pp.1226-1238, 2005.
#
#
# *** MaxRel features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.380
# 2 	 19 	 pc11_me 	 0.226
# 3 	 11 	 MaxPathDistance_me 	 0.217
#
# *** mRMR features ***
# Order 	 Fea 	 Name 	 Score
# 1 	 21 	 pc13_me 	 0.380
# 2 	 5 	 OverallWidth_me 	 1.542
# 3 	 13 	 AverageContraction_me 	 2.241

# %%
### match rows
moran_I_all2 = []
moran_R_full2 = []
moran_me_I2 = []
moran_me_R2 = []
keep_r_ids = []
n = 0
keep_parc_ids = []
for i in moran_r:
    if i in moran_me_r:
        moran_me_I2.append(moran_me_I[moran_me_r.index(i)])
        moran_me_R2.append(region_Rough[i])
        ids_tmp = np.where(np.array(moran_regions)==i)[0]
        ids_tmp2 = np.where(np.array(moran_r_parc)==i)[0]
        p_tmp = np.array(moran_parcID)[ids_tmp]
        p_tmp2 = np.array(moran_parc_ids)[ids_tmp2]
        ids_set = set(p_tmp).intersection(set(p_tmp2))
        tmp_p = []
        for k in list(ids_set):
            tmp_p.append(ids_tmp[np.where(p_tmp == k)[0][0]])
        for j in tmp_p:
            moran_I_all2.append(moran_I_all[j])
            moran_R_full2.append(region_Rough[i])
            keep_parc_ids.append(ids_tmp2[np.where(p_tmp2 == moran_parcID[j])[0][0]])
        keep_r_ids.append(n)
    n += 1

# %%
### match rows
fstd_I_all2 = []
fstd_R_full2 = []
fstd_me_I2 = []
fstd_me_R2 = []
keep_r_ids2 = []
fstd_delta_all2 = []
cv_parc_me2 = []
n = 0
keep_parc_ids2 = []
for i in std_r:
    if i in fstd_me_r:
        fstd_me_I2.append(fstd_me_I[fstd_me_r.index(i)])
        fstd_me_R2.append(region_Rough[i])
        ids_tmp = np.where(np.array(fstd_regions)==i)[0]
        ids_tmp2 = np.where(np.array(std_r_parc)==i)[0]
        p_tmp = np.array(fstd_parcID)[ids_tmp]
        p_tmp2 = np.array(std_parc_ids)[ids_tmp2]
        ids_set = set(p_tmp).intersection(set(p_tmp2))
        tmp_p = []
        for k in list(ids_set):
            tmp_p.append(ids_tmp[np.where(p_tmp == k)[0][0]])
        for j in tmp_p:
            fstd_I_all2.append(fstd_I_all[j])
            fstd_R_full2.append(region_Rough[i])
            fstd_delta_all2.append(fstd_delta_all[j])
            cv_parc_me2.append(cv_parc_me[j])
            keep_parc_ids2.append(ids_tmp2[np.where(p_tmp2 == fstd_parcID[j])[0][0]])
        keep_r_ids2.append(n)
    n += 1

# %%
moran_r2 = np.array(moran_r)[keep_r_ids]
moran_scores2 = np.array(moran_scores)[keep_r_ids]
moran_r_parc2 = np.array(moran_r_parc)[keep_parc_ids]
moran_scores_parc2 = np.array(moran_scores_parc)[keep_parc_ids]

# %%
moran_R = []
for i in moran_r2:
    moran_R.append(region_Rough[i])
moran_R = np.array(moran_R)
moran_R2 = []
for i in moran_r_parc2:
    moran_R2.append(region_Rough[i])
moran_R2 = np.array(moran_R2)

# %%
moran_R_full2 = np.array(moran_R_full2)
moran_me_R2 = np.array(moran_me_R2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
cmap = mpl.cm.rainbow
color_hm = cmap(np.linspace(0,1,len(major_BS_name)-1))
color_hm2 = [mpl.colors.rgb2hex(i,keep_alpha=False) for i in color_hm]

# %%
plt.figure(figsize=(10,2))
current = 0.5
for i in range(len(major_BS_name)-1):
    score_tmp = np.array(moran_me_I2)[moran_me_R2==major_BS_name[i]]
    score_tmp = score_tmp*100
    bin_positions = np.arange(current,len(score_tmp)+current)
    plt.bar(bin_positions,score_tmp,width =0.5,color = color_hm2[i],align='center',edgecolor=color_hm2[i])
    current += len(score_tmp)
# plt.xlabel('Moran I',fontsize=15)
# plt.ylabel('#Sub-parcellation',fontsize=15)
plt.axhline(10,color='magenta',linestyle='--',linewidth=1.2)
plt.axhline(30,color='dimgray',linestyle='--',linewidth=1.2)
plt.axhline(0,color='black',linewidth=1)
plt.tick_params(labelbottom=False,labelleft=True)
plt.yticks([25*i for i in range(-1,4)],[str(0.25*i) for i in range(-1,4)],fontsize = 18)
ax = plt.gca()
for spine in ['right','top','bottom']:
    ax.spines[spine].set_visible(False)
# plt.savefig('all_figs/Fig5/moran_me_regions.png',dpi=300)

# %%
plt.figure(figsize=(10,2))
current = 0.5
for i in range(len(major_BS_name)-1):
    score_tmp = np.array(moran_scores2)[moran_R==major_BS_name[i]]
    score_tmp = score_tmp*100
    # score_tmp = list(score_tmp)
    bin_positions = np.arange(current,len(score_tmp)+current)
    plt.bar(bin_positions,score_tmp,width =0.5,color = color_hm2[i],align='center',edgecolor=color_hm2[i])
    current += len(score_tmp)
# plt.xlabel('Moran I',fontsize=15)
# plt.ylabel('#Sub-parcellation',fontsize=15)
plt.axhline(10,color='magenta',linestyle='--',linewidth=1.2)
plt.axhline(30,color='dimgray',linestyle='--',linewidth=1.2)
plt.axhline(0,color='black',linewidth=1)
plt.tick_params(labelbottom=False,labelleft=True)
plt.yticks([25*i for i in range(-1,4)],[str(0.25*i) for i in range(-1,4)],fontsize = 18)
ax = plt.gca()
for spine in ['right','top','bottom']:
    ax.spines[spine].set_visible(False)
# plt.savefig('all_figs/Fig5/moran_regions.png',dpi=300)
